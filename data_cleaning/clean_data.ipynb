# %%
import pandas as pd

# %%
df = pd.read_csv( "../data/tmdb_response.csv")

# %%
df
# Out:
#       adult                     backdrop_path            genre_ids       id  \
# 0     False  /5lTZyuBTNOfawsfPT8Q0cIg6qAF.jpg             [27, 53]  1339713
# 1     False  /oPsRr7AfNLw6XaPuMpvkWK0bIUA.jpg             [28, 18]  1057265
# 2     False  /xugEpZk9YQ0DIz1aFvH5HGkqpZK.jpg           [27, 9648]  1304313
# 3     False  /e5IdZ1OEWMYxTeu51tI67gXvfpn.jpg         [80, 18, 53]  1433117
# 4     False  /6zg7A9ICOthNR2TSXlT51KvXrsA.jpg        [28, 12, 878]  1228710
# ...     ...                               ...                  ...      ...
# 1135  False   /l9jEItb8GRyhZfny92QeqpCeOu.jpg  [16, 12, 35, 10751]   153518
# 1136  False   /s9kbcVd0PQCw2JPKo9C84ChP2x.jpg      [27, 53, 10749]  1417285
# 1137  False  /dfkE2LppPbJ1qUzi3tdND5iuMFp.jpg             [35, 80]    10607
# 1138  False  /yBCekmb7vK70xUhtsRQBcTu65sB.jpg            [878, 18]      840
# 1139  False  /m3WlBJJRbFPaut1QS0PbOG8Wezy.jpg          [10749, 18]  1327862
#
# ...

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\ANJALI VERMA\OneDrive\Documents\Movie_Recommendation_System-ML\data_cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1140 entries, 0 to 1139
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   adult              1140 non-null   bool
#  1   backdrop_path      1116 non-null   object
#  2   genre_ids          1140 non-null   object
#  3   id                 1140 non-null   int64
#  4   title              1140 non-null   object
#  5   original_language  1140 non-null   object
#  6   original_title     1140 non-null   object
#  7   overview           1128 non-null   object
#  8   popularity         1140 non-null   float64
#  9   poster_path        1139 non-null   object
#  10  release_date       1137 non-null   object
#  11  softcore           1140 non-null   bool
#  12  video              1140 non-null   bool
#  13  vote_average       1140 non-null   float64
#  14  vote_count         1140 non-null   int64
# dtypes: bool(3), float64(2), int64(2), object(8)
# ...

# %%
df.isnull().sum()
# Out:
# adult                 0
# backdrop_path        24
# genre_ids             0
# id                    0
# title                 0
# original_language     0
# original_title        0
# overview             12
# popularity            0
# poster_path           1
# release_date          3
# softcore              0
# video                 0
# vote_average          0
# vote_count            0
# dtype: int64

# %%
df['backdrop_path']=df['backdrop_path'].fillna('not available')

# %%
df["overview"] = df["overview"].fillna("No overview available")
df["poster_path"] = df["poster_path"].fillna("/no-poster.jpg")
df["release_date"] = df["release_date"].fillna("1900-01-01")

# %%
df.isnull().sum()
# Out:
# adult                0
# backdrop_path        0
# genre_ids            0
# id                   0
# title                0
# original_language    0
# original_title       0
# overview             0
# popularity           0
# poster_path          0
# release_date         0
# softcore             0
# video                0
# vote_average         0
# vote_count           0
# dtype: int64
